# %% [markdown]
# <a href="https://colab.research.google.com/github/aldinpramudya/PCVK_Genap_2023/blob/main/JobSheet_1_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jobsheet 1
# ## Aldin Ariel Pramudya
# ## 2141720233
# ## 3D/4

# %% [markdown]
# # Import Library
# ## Step 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Step 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
      "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## Step 3

# %%
height = image_2.shape[0]
width = image_2.shape[1]
print("Resolusi Gambar : ")
print("\n", height, " x ", width)
cv2_imshow(image_2)
# Out:
# Resolusi Gambar :
#
#  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# ## Step 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


#garis horizontal tanpa loop
image_3[int(height/2),:]=[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## Step 5

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (100,200):
  for x in range (100,200):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # Tugas Kelompok
#
# # Kelompok 6
# 1. Aldin Ariel Pramudya
# 2. Aryo Deva Saputra
# 3. Muhammad Ega Rama Fernanda
#
# ## Kelompok 6 tutup Pekerjaan dan kewarganegaraan.

# %%
base_image = io.imread("https://i.pinimg.com/550x/c4/81/29/c48129d4f52fedecae06b9aeacf3cd8f.jpg")
image_1 = cv.cvtColor(base_image, cv.COLOR_BGR2RGB)
cv2_imshow(image_1)
plt.imshow(base_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x349>

# %% [markdown]
# 2.   Kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
#
# **Jawab :**
# Dikarenakan matplotlib membaca warna gambar pada citra itu menggunakan RGB (Red-Green-Blue) yang secara umum sering digunakan pada perangkat lunak dan layar, dan OpenCV membaca warna gambar pada citra itu menggunakan BGR (Blue-Green-Red).
#
# Dengan kata lain, konversi warna BGR ke RGB (BGR2RGB) pada code program tersebut sudah tidak perlu konversi ke OpenCv karena matplotlib membutuhkan warna RGB.

# %% [markdown]
# ## Menutup Pekerjaan dan Kewarganegaraan

# %%
image_1s = np.copy(image_1)
#tutup bagian pekerjaan
for y in range (140,300):
  for x in range (230,250):
    image_1s[x,y] = [0,0,0]
#tutup bagian kewarganegaraan
image_1ss = np.copy(image_1s)
for y in range (140,300):
  for x in range (252,265):
    image_1ss[x,y] = [0,0,255]

final_frame = cv.hconcat((image_1, image_1ss))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x349>
