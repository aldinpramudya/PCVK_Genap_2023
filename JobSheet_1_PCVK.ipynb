# %% [markdown]
# <a href="https://colab.research.google.com/github/aldinpramudya/PCVK_Genap_2023/blob/main/JobSheet_1_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jobsheet 1

# %% [markdown]
# # Import Library
# ## Step 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Step 2

# %%
link = "https://images.mubicdn.net/images/notebook/post_spotlight_images/8689/cache-8689-1647270842/images-w1280.png"

image_1 = io.imread(link)
image_1 = cv.resize(image_1, (0,0), fx=0.5, fy=0.5)
after_image = cv.cvtColor(image_1, cv.COLOR_BGR2RGB)
cv2_imshow(after_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x320>

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
      "https://theglorioblog.files.wordpress.com/2016/04/ibo25girls.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=1280x360>

# %% [markdown]
# ## Step 3

# %%
height = image_2.shape[0]
width = image_2.shape[1]
print("Resolusi Gambar : ")
print("\n", height, " x ", width)
cv2_imshow(image_2)
# Out:
# Resolusi Gambar :
#
#  360  x  640
# <PIL.Image.Image image mode=RGB size=640x360>

# %% [markdown]
# ## Step 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


#garis horizontal tanpa loop
image_3[int(height/2),:]=[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x360>

# %% [markdown]
# ## Step 5

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (100,200):
  for x in range (100,200):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x360>

# %%
from google.colab import drive
drive.mount('/content/drive')
